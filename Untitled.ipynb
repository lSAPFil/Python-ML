# %% [markdown]
# # Нужные библиотеки

# %%
import pandas as pn
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
% matplotlib inline
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator


from sklearn.model_selection import train_test_split 
from sklearn.metrics import classification_report

from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LinearRegression
from sklearn.decomposition import PCA

from sklearn.preprocessing import LabelEncoder

import warnings

import nltk
from nltk.corpus import stopwords

# %% [markdown]
# # Алгоритмы ML

# %%
neighbors=[3,6,9]
train_score=[]
test_score=[]
for neig in neighbors:
    kn = GradientBoostingClassifier(n_estimators=20 , n_iter_no_change=5)
    kn.fit(X_train,y_train)
    train_score.append(kn.score(X_train,y_train))
    test_score.append(kn.score(X_test,y_test))
    
est=[100,200,500]
train_score=[]
val_score=[]
for i in est:
    rfc=RandomForestClassifier(n_estimators=i,n_jobs=-1,verbose=3)
    rfc.fit(X_train,y_train)
    train_score.append(rfc.score(X_train,y_train))
    val_score.append(rfc.score(X_test,y_test))
                      
neighbors=[3,6,9]
train_score=[]
test_score=[]
for neig in neighbors:
    kn = KNeighborsClassifier(n_neighbors=3, n_jobs=-1)
    kn.fit(X_train,y_train)
    train_score.append(kn.score(X_train,y_train))
    test_score.append(kn.score(X_test,y_test))
                      
svc=SVC()
svc.fit(X_train, y_train)
                      
rfc=RandomForestClassifier()
rfc.fit(X_train,y_train)
                      
gnb=GaussianNB()
gnb.fit(X_train.toarray(),y_train)

lr = LinearRegression().fit(X_train, Y_train)
lr.score(X_test, Y_test
         
gbr = GradientBoostingRegressor(n_estimators=500).fit(X_train, Y_train)
gbr.score(X_test, Y_test)
         
dt = DecisionTreeClassifier(max_depth=12).fit(X_train, Y_train)
dt.score(X_test, Y_test)
         
pca = PCA(n_components=500)
pca_feat_x = pca.fit_transform(vect_dict)
                      

                      
X=full.drop(columns="Survived",axis =1)
y=full["Survived"].values
                      
X_train, X_test, y_train, y_test=train_test_split(X,y,train_size=0.8,test_size=0.2)

                      
#Очистка от NaN значений для обучающей выборки
df_train = df_train.fillna(0)
#Так как во время очистки данные перемешиваются, то нужно сделать 
#reset_index для восстановления порядка индекс жлементов
df_train=df_train.reset_index(drop=True)
                      
                      
#Добавление нового датафрейма в словарь
df_sites=pn.DataFrame(data = site.values(), index=site.keys(),columns=["site_id"])
                      
import pickle
fileName="dicTrain.pkl"
with open(fileName, "wb") as fileTrain:
    pickle.dump(dict_train,fileTrain)
                      
                      
                      
df_test=pn.read_csv("offense_codes.csv", encoding='unicode_escape')
                      
df_train=df_train.drop(columns="YEAR", axis=1)
                      
df_train["REPORTING_AREA"]=df_train["REPORTING_AREA"].dropna()
df_train["REPORTING_AREA"]=df_train["REPORTING_AREA"].str.replace(" ","0")
df_train=df_train.reset_index(drop=True)
df_train["SHOOTING"]=df_train["SHOOTING"].fillna("N")
df_test=df_test.reset_index(drop=True)
                      
df["Значимость_раздела"]=pn.to_numeric(df["Значимость_раздела"],errors="coerce")
            
                      
                      
# Работа со стоп-словами. Стоп-слова - слова, которыми можно пожертвовать без потери смысла текста. Используется для
# обработки инфы для определения настроения и поиска его смысла. 
import nltk
from nltk.corpus import stopwords
nltk.download("stopwords")
stop_words_b=stopwords.words("russian")
cvzer=CountVectorizer(stop_words=stop_words_b)
                      
df = df.reset_index() #восстановление порядка индексов
                      
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df["gas_type"] = le.fit_transform(df["gas_type"])

data=pd.read_excel("vigruzka.xlsx")
         
         
def clean_data(df):
    df = df.str.lower()
    df = df.replace(r'[^а-яА-Яa-zA-Z]', ' ', regex = True)
    df = df.str.strip()
    stop_words = stopwords.words("russian")
    df = df.apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_words)]))
    return df
         
to_pred = np.array([[27,0,3.0,1.0,0,168.0,17.0,13.0,21.0,50.0,13.0,18.0,21.0,19.0,51.0,42.0,57.0,58.0,60.0,90.0,43.0,31.0,67.0,43.0,64.0,12.0,38.0,30.0,12.0,68.0,40.0,68.0,15.0,21.0,13.0]])
rfc_predict =rfc.predict(to_pred)

# %% [markdown]
# # Алгоритмы визуализации

# %%
sns.countplot(df_train["target"])

plt.figure(figsize=(20,10))
sns.heatmap(df_train.corr(), annot=True)

df_train.boxplot(figsize=(20,10))

sns.countplot(df_train["OFFENSE_CODE"])

text = data["Признаки_раздела"][0]
# Create and generate a word cloud image:
wordcloud = WordCloud().generate(text)
# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
# %matplotlib inline
sns.pairplot(df,hue="gas_type")

import warnings
warnings.filterwarnings("ignore")
plt.figure(figsize=(10,10))
sns.distplot(data.price)

data.plot(figsize = (25, 25), grid = "on")
