# %% [markdown]
# # Сессия 1.
# ---

# %% [markdown]
# В данной сессии нам необходимо предобработать данные, визуализировать. Подготовить обучающую и тестовую выборку, создать частотный мешок сайтов и подготовить отчет

# %% [markdown]
# ### 1.1 Подготовка тестовой и обучающей выборки.

# %% [markdown]
# В данном задании нам необходимо подготовить данные для дальнейшего анализа и постояния прогнозных моделей. После необходимо выполнить загрузку всех данных. Данные должны быть очищены

# %% [markdown]
# Для того, чтобы загрузить и обработать наши данные, будем использовать следующие библиотеки:

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('df.csv')

# %%
df["Composure"]=df["Composure"].astype(float)
df["Marking"]=df["Marking"].astype(float)
df["StandingTackle"]=df["StandingTackle"].astype(float)
df["SlidingTackle"]=df["SlidingTackle"].astype(float)
df["GKDiving"]=df["GKDiving"].astype(float)
df["GKHandling"]=df["GKHandling"].astype(float)
df["GKKicking"]=df["GKKicking"].astype(float)
df["GKPositioning"]=df["GKPositioning"].astype(float)
df["GKReflexes"]=df["GKReflexes"].astype(float)
df["Penalties"]=df["Penalties"].astype(float)
df["Vision"]=df["Vision"].astype(float)
df["Positioning"]=df["Positioning"].astype(float)
df["Interceptions"]=df["Interceptions"].astype(float)
df["Aggression"]=df["Aggression"].astype(float)
df["LongShots"]=df["LongShots"].astype(float)
df["Strength"]=df["Strength"].astype(float)
df["Stamina"]=df["Stamina"].astype(float)
df["Jumping"]=df["Jumping"].astype(float)
df["ShotPower"]=df["ShotPower"].astype(float)
df["Balance"]=df["Balance"].astype(float)
df["Reactions"]=df["Reactions"].astype(float)
df["Agility"]=df["Agility"].astype(float)
df["SprintSpeed"]=df["SprintSpeed"].astype(float)
df["Acceleration"]=df["Acceleration"].astype(float)
df["BallControl"]=df["BallControl"].astype(float)
df["LongPassing"]=df["LongPassing"].astype(float)
df["FKAccuracy"]=df["FKAccuracy"].astype(float)
df["Curve"]=df["Curve"].astype(float)
df["Dribbling"]=df["Dribbling"].astype(float)
df["Volleys"]=df["Volleys"].astype(float)
df["ShortPassing"]=df["ShortPassing"].astype(float)
df["HeadingAccuracy"]=df["HeadingAccuracy"].astype(float)
df["Finishing"]=df["Finishing"].astype(float)
df["Crossing"]=df["Crossing"].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18207 non-null  int64
#  1   ID                        18207 non-null  int64
#  2   Name                      18207 non-null  object
#  3   Age                       18207 non-null  int64
#  4   Photo                     18207 non-null  object
#  5   Nationality               18207 non-null  object
#  6   Flag                      18207 non-null  object
#  7   Overall                   18207 non-null  int64
#  8   Potential                 18207 non-null  int64
#  9   Club                      17966 non-null  object
#  10  Club Logo                 18207 non-null  object
#  11  Value                     18207 non-null  object
#  12  Wage                      18207 non-null  object
# ...

# %%
df=df.drop(columns=["Unnamed: 0", "Jersey Number","ID"],axis=1)

# %%
df=df.drop(columns=["GKDiving","GKHandling","GKPositioning","GKKicking","GKReflexes","Name",
                    "Work Rate",
                    "Photo",
                    "Nationality",
                    "Flag",
                    "Overall",
                    "Potential",
                    "Club",
                    "Club Logo",
                    "Wage","Value",
                    "Special",
                    "International Reputation",
                    "Real Face",
                    "Joined",
                    "Contract Valid Until",
                    "Loaned From",
                    "Height",
                   "Release Clause"], axis=1)

# %%
df=df.drop(columns=["LS","ST","RS","LW","LF","CF","RF",
                    "RW","LAM","CAM","RAM","LM","LCM",
                    "CM","RCM","RM","LWB","LDM","CDM",
                    "RDM","RWB","LB","LCB","CB","RCB","RB"],axis=1)

# %%
df["Weight"]=df["Weight"].str.replace("lbs","")
df["Weight"] = df["Weight"].astype(float)

# %%
for i in range(0,18206):
    if df["Weight"][i]=="nan":
        df["Weight"][i]=np.nan
        
for i in range(0,18206):
    if df["Weight"][i]==0:
         df["Weight"][i]=np.nan
df["Weight"]= df["Weight"].dropna()

# %%
df["Body Type"]=df["Body Type"].str.replace(".","")

for i in range(0,18206):
    if df["Body Type"][i]!="Lean" and df["Body Type"][i]!="Normal":
        df["Body Type"][i]=np.nan
df["Body Type"]=df["Body Type"].dropna()
# Out:
# <ipython-input-299-6f5b490a629d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Body Type"][i]=np.nan

# %%
df["Preferred Foot"]=df["Preferred Foot"].str.replace("Left","1")
df["Preferred Foot"]=df["Preferred Foot"].str.replace("Right","0")

for i in range(0,18206):
    if df["Preferred Foot"][i]!="1" and df["Preferred Foot"][i]!="0":
        df["Preferred Foot"][i]=np.nan
df["Preferred Foot"]=df["Preferred Foot"].dropna()
# Out:
# <ipython-input-300-506f5c686500>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Preferred Foot"][i]=np.nan

# %%
for i in range(0,18206):
    if df["Position"][i]=="0":
        df["Position"][i]=np.nan
df["Position"]=df["Position"].dropna()

# %%
df=df.dropna()

# %%
df["Preferred Foot"]=df["Preferred Foot"].astype(int)

# %% [markdown]
# Я использовала преобразование NaN значения в 0 так как целесообразно оставить посещение в выборке для корректного обучения машины, а так же преобразовала данные к нормальному типу.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17000 entries, 3 to 18206
# Data columns (total 36 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              17000 non-null  int64
#  1   Preferred Foot   17000 non-null  int32
#  2   Weak Foot        17000 non-null  float64
#  3   Skill Moves      17000 non-null  float64
#  4   Body Type        17000 non-null  object
#  5   Position         17000 non-null  object
#  6   Weight           17000 non-null  float64
#  7   Crossing         17000 non-null  float64
#  8   Finishing        17000 non-null  float64
#  9   HeadingAccuracy  17000 non-null  float64
#  10  ShortPassing     17000 non-null  float64
#  11  Volleys          17000 non-null  float64
#  12  Dribbling        17000 non-null  float64
#  13  Curve            17000 non-null  float64
#  14  FKAccuracy       17000 non-null  float64
#  15  LongPassing      17000 non-null  float64
# ...

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df["Body Type"] = le.fit_transform(df["Body Type"])
df["Position"] = le.fit_transform(df["Position"])
df
# Out:
#        Age  Preferred Foot  Weak Foot  Skill Moves  Body Type  Position  \
# 3       27               0        3.0          1.0          0         5
# 4       27               0        5.0          4.0          1        19
# 5       27               0        4.0          4.0          1        11
# 6       32               0        4.0          4.0          0        19
# 7       31               0        4.0          3.0          1        23
# ...    ...             ...        ...          ...        ...       ...
# 18202   19               0        2.0          2.0          0         4
# 18203   19               0        2.0          2.0          1        26
# 18204   16               0        3.0          2.0          1        26
# 18205   17               0        3.0          2.0          0        24
# 18206   16               0        3.0          2.0          0         4
#
#        Weight  Crossing  Finishing  HeadingAccuracy  ...  LongShots  \
# ...

# %% [markdown]
# Обозначила за таргет столбец  Positioning

# %%
df.to_csv("data.csv")

# %% [markdown]
# Сохраняю очищенный Data Set

# %% [markdown]
# # Итог 1.1

# %% [markdown]
# 1. Данные очищены от NaN значений
# 2. Преобразованы типы данных к нужному формату
# 3. Итоговые выборки сохранены

# %% [markdown]
# # Визуализация данных

# %% [markdown]
# Используя программные средстав, необходимо визуализировать зависимости данных
# В качестве метода буден использован countplot, чтобы посмотреть визуальное распределение нашего таргета

# %%
import seaborn as sns

# %%
sns.countplot(df["Position"])

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(), annot=True)

# %% [markdown]
# ## Заключение

# %% [markdown]
# 1. Тестовая и обучающая выборки подготовленны и сохранены в csv формате. Отражено в отчете
# 2. Данные провизуализированны
# 3. Отчет подготовлен

# %% [markdown]
# # Сессия 2. Построение модели машинного обучения

# %% [markdown]
# В данном модуле необходимо продолжить работать с данными, подготовленными в предыдущем модуле. На основе предобработанных данных необходимо построить и обучить модель классификации, а также добиться наиболее точной работы построенной модели.

# %% [markdown]
# ### Разделение выборки на обучающую и отложенную

# %%
X=df.drop(columns="Position")
Y=df["Position"].values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,train_size=0.8, test_size=0.2)

# %% [markdown]
# ## Алгоритм случайного леса

# %%
from sklearn.ensemble import RandomForestClassifier
forest=[200,400,600]
train_score=[]
test_score=[]
for fore in forest:
    rfc = RandomForestClassifier(n_estimators=3, n_jobs=-1)
    rfc.fit(X_train,Y_train)
    train_score.append(rfc.score(X_train,Y_train))
    test_score.append(rfc.score(X_test,Y_test))

# %%
train_score
# Out:
# [0.88875, 0.8891911764705882, 0.8846323529411765]

# %%
test_score
# Out:
# [0.44882352941176473, 0.45323529411764707, 0.44058823529411767]

# %%
df.head(1)
# Out:
#    Age  Preferred Foot  Weak Foot  Skill Moves  Body Type  Position  Weight  \
# 3   27               0        3.0          1.0          0         5   168.0
#
#    Crossing  Finishing  HeadingAccuracy  ...  LongShots  Aggression  \
# 3      17.0       13.0             21.0  ...       12.0        38.0
#
#    Interceptions  Positioning  Vision  Penalties  Composure  Marking  \
# 3           30.0         12.0    68.0       40.0       68.0     15.0
#
#    StandingTackle  SlidingTackle
# 3            21.0           13.0
#
# [1 rows x 36 columns]

# %%
to_pred = np.array([[27,0,3.0,1.0,0,168.0,17.0,13.0,21.0,50.0,13.0,18.0,21.0,19.0,51.0,42.0,57.0,58.0,60.0,90.0,43.0,31.0,67.0,43.0,64.0,12.0,38.0,30.0,12.0,68.0,40.0,68.0,15.0,21.0,13.0]])
rfc_predict =rfc.predict(to_pred)
rfc_predict
# Out:
# array([5])

# %% [markdown]
# # Заключение

# %% [markdown]
# В данной работе я подготовила наши данные для обучении машины с использованием таких библиотек как: numpy, pandas, sklearn.
# Затем использовали метод машинного обучения: Алгоритм случайного леса

# %% [markdown]
# Задача данной ВКР позволяет решить проблемы футболистов с выбором позиции на поле на основе физических данных игроков, а так же помогает определить недостающие физические качества, для их будущей корректировки.
